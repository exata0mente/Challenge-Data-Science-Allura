# %% [markdown]
# ## Base de Dados - Visualização

# %% [markdown]
# Agora vamos dar uma visibilidade aos dados, preferencialmente à variavel `Churn`.
#
# Vamos lá

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_json('../Dados/dados_tratados.json')
df.head()
# Out:
#    id_cliente fl_inativo       sexo fl_maior_65_anos fl_tem_parceiro  \
# 0  0002-ORFBO        Não   Feminino              Não             Sim
# 1  0003-MKNFE        Não  Masculino              Não             Não
# 2  0004-TLHLJ        Sim  Masculino              Não             Não
# 3  0011-IGKFF        Sim  Masculino              Sim             Sim
# 4  0013-EXCHZ        Sim   Feminino              Sim             Sim
#
#   fl_dependentes  meses_contrato fl_servico_telefonico fl_multiplas_linhas  \
# 0            Sim               9                   Sim                 Não
# 1            Não               9                   Sim                 Sim
# 2            Não               4                   Sim                 Não
# 3            Não              13                   Sim                 Não
# 4            Não               3                   Sim                 Não
#
#   tipo_servico_internet  ... fl_servico_protecao_dispositivo  \
# 0                   DSL  ...                             Não
# 1                   DSL  ...                             Não
# 2           Fibra ótica  ...                             Sim
# 3           Fibra ótica  ...                             Sim
# 4           Fibra ótica  ...                             Não
#
#   fl_servico_suporte_tech fl_servico_tv_cabo fl_servico_stream tipo_contrato  \
# 0                     Sim                Sim               Não         Anual
# 1                     Não                Não               Sim        Mensal
# 2                     Não                Não               Não        Mensal
# 3                     Não                Sim               Sim        Mensal
# 4                     Sim                Sim               Não        Mensal
#
#   fl_sem_papel valor_servico_diario       tipo_pagamento  \
# 0          Sim                 2.19    Cheque (Correios)
# 1          Não                 2.00    Cheque (Correios)
# 2          Sim                 2.46  Cheque (Eletrônico)
# 3          Sim                 3.27  Cheque (Eletrônico)
# 4          Sim                 2.80    Cheque (Correios)
#
#    valor_servico_mensal valor_servico_total
# 0                  65.6              593.30
# 1                  59.9              542.40
# 2                  73.9              280.85
# 3                  98.0             1237.85
# 4                  83.9              267.40
#
# [5 rows x 22 columns]

# %% [markdown]
# A nossa variável de estudo será a `Churn`, neste momento vou tirar os dados faltantes

# %%
df_churn = df.dropna(subset=['fl_inativo']).copy()
df_churn.head()
# Out:
#    id_cliente fl_inativo       sexo fl_maior_65_anos fl_tem_parceiro  \
# 0  0002-ORFBO        Não   Feminino              Não             Sim
# 1  0003-MKNFE        Não  Masculino              Não             Não
# 2  0004-TLHLJ        Sim  Masculino              Não             Não
# 3  0011-IGKFF        Sim  Masculino              Sim             Sim
# 4  0013-EXCHZ        Sim   Feminino              Sim             Sim
#
#   fl_dependentes  meses_contrato fl_servico_telefonico fl_multiplas_linhas  \
# 0            Sim               9                   Sim                 Não
# 1            Não               9                   Sim                 Sim
# 2            Não               4                   Sim                 Não
# 3            Não              13                   Sim                 Não
# 4            Não               3                   Sim                 Não
#
#   tipo_servico_internet  ... fl_servico_protecao_dispositivo  \
# 0                   DSL  ...                             Não
# 1                   DSL  ...                             Não
# 2           Fibra ótica  ...                             Sim
# 3           Fibra ótica  ...                             Sim
# 4           Fibra ótica  ...                             Não
#
#   fl_servico_suporte_tech fl_servico_tv_cabo fl_servico_stream tipo_contrato  \
# 0                     Sim                Sim               Não         Anual
# 1                     Não                Não               Sim        Mensal
# 2                     Não                Não               Não        Mensal
# 3                     Não                Sim               Sim        Mensal
# 4                     Sim                Sim               Não        Mensal
#
#   fl_sem_papel valor_servico_diario       tipo_pagamento  \
# 0          Sim                 2.19    Cheque (Correios)
# 1          Não                 2.00    Cheque (Correios)
# 2          Sim                 2.46  Cheque (Eletrônico)
# 3          Sim                 3.27  Cheque (Eletrônico)
# 4          Sim                 2.80    Cheque (Correios)
#
#    valor_servico_mensal valor_servico_total
# 0                  65.6              593.30
# 1                  59.9              542.40
# 2                  73.9              280.85
# 3                  98.0             1237.85
# 4                  83.9              267.40
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Analisar a variável target: Churn

# %%
contagem_churn = df_churn.fl_inativo.value_counts(normalize=True) * 100
print("{:.1f}% da nossa base tornaram-se inativos (churn)".format(contagem_churn[1]))
# Out:
# 26.5% da nossa base tornaram-se inativos (churn)

# %% [markdown]
# ## Visualizar a distribuição da variável target: Churn

# %% [markdown]
# Vou definir uma função que vai facilitar meu trabalho na analise de variáveis categóricas

# %%
def conta_relacao_categoricos(x, colA, colB):
    if(x[colA].dtype) == 'O' and (x[colB].dtype) == 'O' :
        return pd.crosstab(index = x[colA], columns = x[colB], normalize = 'columns') * 100
    else:
        print('Uma ou mais colunas não são do tipo categorico')

# %%
for coluna in df_churn.columns:
    print("A coluna {} é do tipo {}".format(coluna, df_churn[coluna].dtype))
# Out:
# A coluna id_cliente é do tipo object
# A coluna fl_inativo é do tipo object
# A coluna sexo é do tipo object
# A coluna fl_maior_65_anos é do tipo object
# A coluna fl_tem_parceiro é do tipo object
# A coluna fl_dependentes é do tipo object
# A coluna meses_contrato é do tipo int64
# A coluna fl_servico_telefonico é do tipo object
# A coluna fl_multiplas_linhas é do tipo object
# A coluna tipo_servico_internet é do tipo object
# A coluna fl_servico_seguranca_online é do tipo object
# A coluna fl_servico_backup_online é do tipo object
# A coluna fl_servico_protecao_dispositivo é do tipo object
# A coluna fl_servico_suporte_tech é do tipo object
# A coluna fl_servico_tv_cabo é do tipo object
# A coluna fl_servico_stream é do tipo object
# A coluna tipo_contrato é do tipo object
# A coluna fl_sem_papel é do tipo object
# A coluna valor_servico_diario é do tipo float64
# A coluna tipo_pagamento é do tipo object
# A coluna valor_servico_mensal é do tipo float64
# A coluna valor_servico_total é do tipo float64

# %% [markdown]
# ## Visualizar a distribuição da variável target: Churn

# %% [markdown]
# ### Analisando as variáveis categoricas em relação ao Churn

# %% [markdown]
# #### Sexo

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'sexo')
# Out:
# sexo         Feminino  Masculino
# fl_inativo
# Não         73.079128  73.839662
# Sim         26.920872  26.160338

# %% [markdown]
# O sexo não aparenta tendência em churn

# %% [markdown]
# #### 65 anos

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_maior_65_anos')
# Out:
# fl_maior_65_anos        Não        Sim
# fl_inativo
# Não               76.393832  58.318739
# Sim               23.606168  41.681261

# %% [markdown]
# Ter mais de 65 anos aparenta maior chance de churn

# %% [markdown]
# #### Parceiro

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_tem_parceiro')
# Out:
# fl_tem_parceiro        Não        Sim
# fl_inativo
# Não              67.042021  80.335097
# Sim              32.957979  19.664903

# %% [markdown]
# #### Dependentes

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_dependentes')
# Out:
# fl_dependentes       Não        Sim
# fl_inativo
# Não             68.72086  84.549763
# Sim             31.27914  15.450237

# %% [markdown]
# #### Serviço Telefônico

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_servico_telefonico')
# Out:
# fl_servico_telefonico        Não        Sim
# fl_inativo
# Não                    75.073314  73.290363
# Sim                    24.926686  26.709637

# %% [markdown]
# O serviço telefônico não aparenta ter tendência a churn

# %% [markdown]
# Como os tipos de serviços estão atrelados a posse de um serviço telefônico, irei assumir a hipótese de que o serviço telefônico não aparenta ter tendência a churn

# %% [markdown]
# #### Serviço Internet

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'tipo_servico_internet')
# Out:
# tipo_servico_internet        DSL  Fibra ótica    Nenhum
# fl_inativo
# Não                    81.040892    58.107235  92.59502
# Sim                    18.959108    41.892765   7.40498

# %% [markdown]
# Ter um serviço de internet, principalmente fibra ótica, tem forte relação ao churn!

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_servico_seguranca_online')
# Out:
# fl_servico_seguranca_online        Não        Sim
# fl_inativo
# Não                          68.670382  85.388806
# Sim                          31.329618  14.611194

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_servico_backup_online')
# Out:
# fl_servico_backup_online        Não        Sim
# fl_inativo
# Não                       70.827915  78.468506
# Sim                       29.172085  21.531494

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_servico_protecao_dispositivo')
# Out:
# fl_servico_protecao_dispositivo        Não        Sim
# fl_inativo
# Não                              71.348193  77.497936
# Sim                              28.651807  22.502064

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_servico_suporte_tech')
# Out:
# fl_servico_suporte_tech        Não        Sim
# fl_inativo
# Não                      68.813763  84.833659
# Sim                      31.186237  15.166341

# %% [markdown]
# Não ter suporte técnico tem relação ao churn

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_servico_tv_cabo')
# Out:
# fl_servico_tv_cabo        Não        Sim
# fl_inativo
# Não                 75.668819  69.929812
# Sim                 24.331181  30.070188

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_servico_stream')
# Out:
# fl_servico_stream        Não        Sim
# fl_inativo
# Não                75.620506  70.058565
# Sim                24.379494  29.941435

# %% [markdown]
# #### Tipo de contrato

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'tipo_contrato')
# Out:
# tipo_contrato      Anual     Bienal     Mensal
# fl_inativo
# Não            88.730482  97.168142  57.290323
# Sim            11.269518   2.831858  42.709677

# %% [markdown]
# Contratos mensais tiveram mais efeitos de churn

# %% [markdown]
# #### _Paperless_

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'fl_sem_papel')
# Out:
# fl_sem_papel        Não        Sim
# fl_inativo
# Não           83.669916  66.434908
# Sim           16.330084  33.565092

# %% [markdown]
# #### Tipo de pagamento

# %%
conta_relacao_categoricos(x=df_churn, colA = 'fl_inativo', colB = 'tipo_pagamento')
# Out:
# tipo_pagamento  Cartão de Crédito  Cheque (Correios)  Cheque (Eletrônico)  \
# fl_inativo
# Não                     84.756899            80.8933            54.714588
# Sim                     15.243101            19.1067            45.285412
#
# tipo_pagamento  Transferência Bancária
# fl_inativo
# Não                          83.290155
# Sim                          16.709845

# %% [markdown]
# Cheque eletrônicos teve grande importância no churn

# %% [markdown]
# ### Conclusões para as variáveis categóricas

# %% [markdown]
# As variávies que tem maior relação com o churn são:
#
# 1. **Tem 65 anos**: Sim
# 1. **Serviço de Internet**: Fibra Ótica
# 1. **Tipo de contrato**: Mensal
# 1. **Tipo de pagamento**: Cheque Eletrônico

# %% [markdown]
# ### Analisando as variáveis quantitativas em relação ao Churn

# %%
df_churn.head()
# Out:
#    id_cliente fl_inativo       sexo fl_maior_65_anos fl_tem_parceiro  \
# 0  0002-ORFBO        Não   Feminino              Não             Sim
# 1  0003-MKNFE        Não  Masculino              Não             Não
# 2  0004-TLHLJ        Sim  Masculino              Não             Não
# 3  0011-IGKFF        Sim  Masculino              Sim             Sim
# 4  0013-EXCHZ        Sim   Feminino              Sim             Sim
#
#   fl_dependentes  meses_contrato fl_servico_telefonico fl_multiplas_linhas  \
# 0            Sim               9                   Sim                 Não
# 1            Não               9                   Sim                 Sim
# 2            Não               4                   Sim                 Não
# 3            Não              13                   Sim                 Não
# 4            Não               3                   Sim                 Não
#
#   tipo_servico_internet  ... fl_servico_protecao_dispositivo  \
# 0                   DSL  ...                             Não
# 1                   DSL  ...                             Não
# 2           Fibra ótica  ...                             Sim
# 3           Fibra ótica  ...                             Sim
# 4           Fibra ótica  ...                             Não
#
#   fl_servico_suporte_tech fl_servico_tv_cabo fl_servico_stream tipo_contrato  \
# 0                     Sim                Sim               Não         Anual
# 1                     Não                Não               Sim        Mensal
# 2                     Não                Não               Não        Mensal
# 3                     Não                Sim               Sim        Mensal
# 4                     Sim                Sim               Não        Mensal
#
#   fl_sem_papel valor_servico_diario       tipo_pagamento  \
# 0          Sim                 2.19    Cheque (Correios)
# 1          Não                 2.00    Cheque (Correios)
# 2          Sim                 2.46  Cheque (Eletrônico)
# 3          Sim                 3.27  Cheque (Eletrônico)
# 4          Sim                 2.80    Cheque (Correios)
#
#    valor_servico_mensal valor_servico_total
# 0                  65.6              593.30
# 1                  59.9              542.40
# 2                  73.9              280.85
# 3                  98.0             1237.85
# 4                  83.9              267.40
#
# [5 rows x 22 columns]

# %%
sns.violinplot(data=df_churn, x='fl_inativo', y='meses_contrato');

# %% [markdown]
# Indicação de que o churn está mais concentrado nos contratos de menores periodos

# %%
sns.displot(df_churn, y='meses_contrato', hue='fl_inativo', multiple='stack');

# %%
sns.displot(df_churn, x='meses_contrato', col='fl_inativo');

# %% [markdown]
# Vou explorar um pouco a questão do tempo de contrato

# %%
sns.displot(df_churn, y='meses_contrato', col='fl_inativo', hue='fl_maior_65_anos', multiple='stack');

# %%
sns.displot(df_churn, y='meses_contrato', col='fl_inativo', hue='tipo_servico_internet', multiple='stack');

# %% [markdown]
# Fibra ótica destoa muito dos outros serviços

# %%
sns.displot(df_churn, y='meses_contrato', col='fl_inativo', hue='tipo_contrato', multiple='stack');

# %% [markdown]
# Os contratos mensais aparentam ser problematicos

# %%
sns.displot(df_churn, y='meses_contrato', col='fl_inativo', hue='tipo_pagamento', multiple='stack');

# %% [markdown]
# Analisando os valores de serviço

# %%
sns.boxplot(data=df_churn, x='fl_inativo', y='valor_servico_total');

# %% [markdown]
# Um tanto quanto óbvio assumir que os inativos gastaram menos do que os ativos ...

# %%
sns.boxplot(data=df_churn, x='fl_inativo', y='valor_servico_mensal');

# %% [markdown]
# ... Mas se olhar os valores mensais praticados é maior entre os que sairam. Interessante

# %%
sns.catplot(data=df_churn, x='fl_inativo', y='valor_servico_mensal')

# %%
sns.relplot(data=df_churn, x='meses_contrato', y='valor_servico_total', hue='fl_inativo')

# %%
sns.relplot(data=df_churn, x='meses_contrato', y='valor_servico_total', col='fl_inativo')

# %% [markdown]
# Os churns estão mais concentrados nos maiores valores de contrato

# %%
sns.catplot(data=df_churn, y='valor_servico_total', x='tipo_servico_internet')

# %%
sns.catplot(data=df_churn, y='valor_servico_mensal', x='tipo_servico_internet')

# %% [markdown]
# O serviço de Fibra ótica, que tem grande proporção no Churn tem os maiores valores de serviços praticados. Os valores altos como vimos está presente nos clientes que se inativaram

# %%
sns.catplot(data=df_churn.query("tipo_servico_internet == 'Fibra ótica'"), 
            y='valor_servico_total', 
            x='tipo_contrato')

# %%
sns.catplot(data=df_churn.query("tipo_servico_internet == 'Fibra ótica'"), 
            y='valor_servico_total', 
            x='tipo_pagamento')

# %% [markdown]
# ### Analisar a correlação das variáveis

# %% [markdown]
# Para trazer as correlações irei transformar os dados categoricos em númericos. Para os que possuem mais de um valor ou não representam 'Sim / Não' irei atribuir um peso conforme a sua relação com o churn. (Isso vai enviezar, eu sei)

# %%
df_churn.columns
# Out:
# Index(['id_cliente', 'fl_inativo', 'sexo', 'fl_maior_65_anos',
#        'fl_tem_parceiro', 'fl_dependentes', 'meses_contrato',
#        'fl_servico_telefonico', 'fl_multiplas_linhas', 'tipo_servico_internet',
#        'fl_servico_seguranca_online', 'fl_servico_backup_online',
#        'fl_servico_protecao_dispositivo', 'fl_servico_suporte_tech',
#        'fl_servico_tv_cabo', 'fl_servico_stream', 'tipo_contrato',
#        'fl_sem_papel', 'valor_servico_diario', 'tipo_pagamento',
#        'valor_servico_mensal', 'valor_servico_total'],
#       dtype='object')

# %% [markdown]
# Começando pelas variáveis de flag

# %%
df_corr = df_churn.copy()

# %%
sim_nao = {'Sim': 1, 'Não': 0}
colunas = df_corr.filter(like='fl_').columns
for coluna in colunas:
    df_corr[coluna].replace(sim_nao, inplace=True)
df_corr.head()
# Out:
#    id_cliente  fl_inativo       sexo  fl_maior_65_anos  fl_tem_parceiro  \
# 0  0002-ORFBO           0   Feminino                 0                1
# 1  0003-MKNFE           0  Masculino                 0                0
# 2  0004-TLHLJ           1  Masculino                 0                0
# 3  0011-IGKFF           1  Masculino                 1                1
# 4  0013-EXCHZ           1   Feminino                 1                1
#
#    fl_dependentes  meses_contrato  fl_servico_telefonico  fl_multiplas_linhas  \
# 0               1               9                      1                    0
# 1               0               9                      1                    1
# 2               0               4                      1                    0
# 3               0              13                      1                    0
# 4               0               3                      1                    0
#
#   tipo_servico_internet  ...  fl_servico_protecao_dispositivo  \
# 0                   DSL  ...                                0
# 1                   DSL  ...                                0
# 2           Fibra ótica  ...                                1
# 3           Fibra ótica  ...                                1
# 4           Fibra ótica  ...                                0
#
#    fl_servico_suporte_tech  fl_servico_tv_cabo  fl_servico_stream  \
# 0                        1                   1                  0
# 1                        0                   0                  1
# 2                        0                   0                  0
# 3                        0                   1                  1
# 4                        1                   1                  0
#
#    tipo_contrato  fl_sem_papel valor_servico_diario       tipo_pagamento  \
# 0          Anual             1                 2.19    Cheque (Correios)
# 1         Mensal             0                 2.00    Cheque (Correios)
# 2         Mensal             1                 2.46  Cheque (Eletrônico)
# 3         Mensal             1                 3.27  Cheque (Eletrônico)
# 4         Mensal             1                 2.80    Cheque (Correios)
#
#    valor_servico_mensal valor_servico_total
# 0                  65.6              593.30
# 1                  59.9              542.40
# 2                  73.9              280.85
# 3                  98.0             1237.85
# 4                  83.9              267.40
#
# [5 rows x 22 columns]

# %% [markdown]
# A variável `tipo_servico_internet` vimos que tem grande participação no Churn. Por não ser possível ordená-la irei utilizar o Encoding, visto no [curso](https://cursos.alura.com.br/course/modelos-preditivos-dados-deteccao-fraude) de _Machine Learning_

# %%
df_corr = pd.get_dummies(data=df_corr, columns=['tipo_servico_internet', 'tipo_contrato', 'tipo_pagamento'])

# %%
df_corr.columns
# Out:
# Index(['id_cliente', 'fl_inativo', 'sexo', 'fl_maior_65_anos',
#        'fl_tem_parceiro', 'fl_dependentes', 'meses_contrato',
#        'fl_servico_telefonico', 'fl_multiplas_linhas',
#        'fl_servico_seguranca_online', 'fl_servico_backup_online',
#        'fl_servico_protecao_dispositivo', 'fl_servico_suporte_tech',
#        'fl_servico_tv_cabo', 'fl_servico_stream', 'fl_sem_papel',
#        'valor_servico_diario', 'valor_servico_mensal', 'valor_servico_total',
#        'tipo_servico_internet_DSL', 'tipo_servico_internet_Fibra ótica',
#        'tipo_servico_internet_Nenhum', 'tipo_contrato_Anual',
#        'tipo_contrato_Bienal', 'tipo_contrato_Mensal',
#        'tipo_pagamento_Cartão de Crédito', 'tipo_pagamento_Cheque (Correios)',
#        'tipo_pagamento_Cheque (Eletrônico)',
#        'tipo_pagamento_Transferência Bancária'],
#       dtype='object')

# %% [markdown]
# Vou melhorar um pouco estas colunas

# %%
colunas_nome = {
    'tipo_servico_internet_DSL': 'fl_servico_internet_dsl', 
    'tipo_servico_internet_Fibra ótica': 'fl_servico_internet_fibra_otica',
    'tipo_servico_internet_Nenhum': 'fl_sem_servico_internet', 
    'tipo_contrato_Anual': 'fl_contrato_anual',
    'tipo_contrato_Bienal': 'fl_contrato_bienal', 
    'tipo_contrato_Mensal': 'fl_contrato_mensal',
    'tipo_pagamento_Cartão de Crédito': 'fl_pagamento_ccredito',
    'tipo_pagamento_Cheque (Correios)': 'fl_pagamento_cheque_correio',
    'tipo_pagamento_Cheque (Eletrônico)': 'fl_pagamento_cheque_eletronico',
    'tipo_pagamento_Transferência Bancária': 'fl_pagamento_transf_bancaria'
}
df_corr.rename(columns=colunas_nome, inplace=True)

# %%
df_corr.corr()
# Out:
#                                  fl_inativo  fl_maior_65_anos  \
# fl_inativo                         1.000000          0.150889
# fl_maior_65_anos                   0.150889          1.000000
# fl_tem_parceiro                   -0.150448          0.016479
# fl_dependentes                    -0.164221         -0.211185
# meses_contrato                    -0.352229          0.016567
# fl_servico_telefonico              0.011942          0.008576
# fl_multiplas_linhas                0.040102          0.142948
# fl_servico_seguranca_online       -0.171226         -0.038653
# fl_servico_backup_online          -0.082255          0.066572
# fl_servico_protecao_dispositivo   -0.066160          0.059428
# fl_servico_suporte_tech           -0.164674         -0.060625
# fl_servico_tv_cabo                 0.063228          0.105378
# fl_servico_stream                  0.061382          0.120176
# fl_sem_papel                       0.191825          0.156530
# valor_servico_diario               0.193412          0.220147
# valor_servico_mensal               0.193356          0.220173
# valor_servico_total               -0.198347          0.102997
# fl_servico_internet_dsl           -0.124214         -0.108322
# fl_servico_internet_fibra_otica    0.308020          0.255338
# fl_sem_servico_internet           -0.227890         -0.182742
# fl_contrato_anual                 -0.177820         -0.046262
# fl_contrato_bienal                -0.302253         -0.117000
# fl_contrato_mensal                 0.405103          0.138360
# fl_pagamento_ccredito             -0.134302         -0.024135
# fl_pagamento_cheque_correio       -0.091683         -0.153477
# fl_pagamento_cheque_eletronico     0.301919          0.171718
# fl_pagamento_transf_bancaria      -0.117937         -0.016159
#
#                                  fl_tem_parceiro  fl_dependentes  \
# fl_inativo                             -0.150448       -0.164221
# fl_maior_65_anos                        0.016479       -0.211185
# fl_tem_parceiro                         1.000000        0.452676
# fl_dependentes                          0.452676        1.000000
# meses_contrato                          0.379697        0.159712
# fl_servico_telefonico                   0.017706       -0.001762
# fl_multiplas_linhas                     0.142057       -0.024526
# fl_servico_seguranca_online             0.143106        0.080972
# fl_servico_backup_online                0.141498        0.023671
# fl_servico_protecao_dispositivo         0.153786        0.013963
# fl_servico_suporte_tech                 0.119999        0.063268
# fl_servico_tv_cabo                      0.124666       -0.016558
# fl_servico_stream                       0.117412       -0.039741
# fl_sem_papel                           -0.014877       -0.111377
# valor_servico_diario                    0.096909       -0.113939
# valor_servico_mensal                    0.096848       -0.113890
# valor_servico_total                     0.317532        0.062124
# fl_servico_internet_dsl                -0.000851        0.052010
# fl_servico_internet_fibra_otica         0.000304       -0.165818
# fl_sem_servico_internet                 0.000615        0.139812
# fl_contrato_anual                       0.082783        0.068368
# fl_contrato_bienal                      0.248091        0.204613
# fl_contrato_mensal                     -0.280865       -0.231720
# fl_pagamento_ccredito                   0.082029        0.060267
# fl_pagamento_cheque_correio            -0.095125        0.059071
# fl_pagamento_cheque_eletronico         -0.083852       -0.150642
# fl_pagamento_transf_bancaria            0.110706        0.052021
#
#                                  meses_contrato  fl_servico_telefonico  \
# fl_inativo                            -0.352229               0.011942
# fl_maior_65_anos                       0.016567               0.008576
# fl_tem_parceiro                        0.379697               0.017706
# fl_dependentes                         0.159712              -0.001762
# meses_contrato                         1.000000               0.008448
# fl_servico_telefonico                  0.008448               1.000000
# fl_multiplas_linhas                    0.331941               0.279690
# fl_servico_seguranca_online            0.327203              -0.092893
# fl_servico_backup_online               0.360277              -0.052312
# fl_servico_protecao_dispositivo        0.360653              -0.071227
# fl_servico_suporte_tech                0.324221              -0.096340
# fl_servico_tv_cabo                     0.279756              -0.022574
# fl_servico_stream                      0.286111              -0.032959
# fl_sem_papel                           0.006152               0.016505
# valor_servico_diario                   0.247910               0.247361
# valor_servico_mensal                   0.247900               0.247398
# valor_servico_total                    0.826164               0.113203
# fl_servico_internet_dsl                0.013274              -0.452425
# fl_servico_internet_fibra_otica        0.019720               0.289999
# fl_sem_servico_internet               -0.039062               0.172209
# fl_contrato_anual                      0.202570              -0.002791
# fl_contrato_bienal                     0.558533               0.003519
# fl_contrato_mensal                    -0.645561              -0.000742
# fl_pagamento_ccredito                  0.233006              -0.007721
# fl_pagamento_cheque_correio           -0.233852              -0.003319
# fl_pagamento_cheque_eletronico        -0.208363               0.003062
# fl_pagamento_transf_bancaria           0.243510               0.007556
#
#                                  fl_multiplas_linhas  \
# fl_inativo                                  0.040102
# fl_maior_65_anos                            0.142948
# fl_tem_parceiro                             0.142057
# fl_dependentes                             -0.024526
# meses_contrato                              0.331941
# fl_servico_telefonico                       0.279690
# fl_multiplas_linhas                         1.000000
# fl_servico_seguranca_online                 0.098108
# fl_servico_backup_online                    0.202237
# fl_servico_protecao_dispositivo             0.201137
# fl_servico_suporte_tech                     0.100571
# fl_servico_tv_cabo                          0.257152
# fl_servico_stream                           0.258751
# fl_sem_papel                                0.163530
# valor_servico_diario                        0.490457
# valor_servico_mensal                        0.490434
# valor_servico_total                         0.468516
# fl_servico_internet_dsl                    -0.199920
# fl_servico_internet_fibra_otica             0.366083
# fl_sem_servico_internet                    -0.210564
# fl_contrato_anual                          -0.003794
# fl_contrato_bienal                          0.106253
# fl_contrato_mensal                         -0.088203
# fl_pagamento_ccredito                       0.060048
# fl_pagamento_cheque_correio                -0.227206
# fl_pagamento_cheque_eletronico              0.083618
# fl_pagamento_transf_bancaria                0.075527
#
#                                  fl_servico_seguranca_online  \
# fl_inativo                                         -0.171226
# fl_maior_65_anos                                   -0.038653
# fl_tem_parceiro                                     0.143106
# fl_dependentes                                      0.080972
# meses_contrato                                      0.327203
# fl_servico_telefonico                              -0.092893
# fl_multiplas_linhas                                 0.098108
# fl_servico_seguranca_online                         1.000000
# fl_servico_backup_online                            0.283832
# fl_servico_protecao_dispositivo                     0.275438
# fl_servico_suporte_tech                             0.354931
# fl_servico_tv_cabo                                  0.176207
# fl_servico_stream                                   0.187398
# fl_sem_papel                                       -0.003636
# valor_servico_diario                                0.296591
# valor_servico_mensal                                0.296594
# valor_servico_total                                 0.411679
# fl_servico_internet_dsl                             0.321269
# fl_servico_internet_fibra_otica                    -0.030696
# fl_sem_servico_internet                            -0.333403
# fl_contrato_anual                                   0.100162
# fl_contrato_bienal                                  0.191773
# fl_contrato_mensal                                 -0.246679
# fl_pagamento_ccredito                               0.115721
# fl_pagamento_cheque_correio                        -0.080798
# fl_pagamento_cheque_eletronico                     -0.112338
# fl_pagamento_transf_bancaria                        0.095158
#
#                                  fl_servico_backup_online  \
# fl_inativo                                      -0.082255
# fl_maior_65_anos                                 0.066572
# fl_tem_parceiro                                  0.141498
# fl_dependentes                                   0.023671
# meses_contrato                                   0.360277
# fl_servico_telefonico                           -0.052312
# fl_multiplas_linhas                              0.202237
# fl_servico_seguranca_online                      0.283832
# fl_servico_backup_online                         1.000000
# fl_servico_protecao_dispositivo                  0.303546
# fl_servico_suporte_tech                          0.294233
# fl_servico_tv_cabo                               0.282106
# fl_servico_stream                                0.274501
# fl_sem_papel                                     0.126735
# valor_servico_diario                             0.441762
# valor_servico_mensal                             0.441780
# valor_servico_total                              0.509256
# fl_servico_internet_dsl                          0.157884
# fl_servico_internet_fibra_otica                  0.165651
# fl_sem_servico_internet                         -0.381593
# fl_contrato_anual                                0.083722
# fl_contrato_bienal                               0.111400
# fl_contrato_mensal                              -0.164172
# fl_pagamento_ccredito                            0.090785
# fl_pagamento_cheque_correio                     -0.174164
# fl_pagamento_cheque_eletronico                  -0.000408
# fl_pagamento_transf_bancaria                     0.087004
#
#                                  fl_servico_protecao_dispositivo  ...  \
# fl_inativo                                             -0.066160  ...
# fl_maior_65_anos                                        0.059428  ...
# fl_tem_parceiro                                         0.153786  ...
# fl_dependentes                                          0.013963  ...
# meses_contrato                                          0.360653  ...
# fl_servico_telefonico                                  -0.071227  ...
# fl_multiplas_linhas                                     0.201137  ...
# fl_servico_seguranca_online                             0.275438  ...
# fl_servico_backup_online                                0.303546  ...
# fl_servico_protecao_dispositivo                         1.000000  ...
# fl_servico_suporte_tech                                 0.333313  ...
# fl_servico_tv_cabo                                      0.390874  ...
# fl_servico_stream                                       0.402111  ...
# fl_sem_papel                                            0.103797  ...
# valor_servico_diario                                    0.482648  ...
# valor_servico_mensal                                    0.482692  ...
# valor_servico_total                                     0.522012  ...
# fl_servico_internet_dsl                                 0.146291  ...
# fl_servico_internet_fibra_otica                         0.176049  ...
# fl_sem_servico_internet                                -0.380754  ...
# fl_contrato_anual                                       0.102495  ...
# fl_contrato_bienal                                      0.165096  ...
# fl_contrato_mensal                                     -0.225662  ...
# fl_pagamento_ccredito                                   0.111554  ...
# fl_pagamento_cheque_correio                            -0.187373  ...
# fl_pagamento_cheque_eletronico                         -0.003351  ...
# fl_pagamento_transf_bancaria                            0.083115  ...
#
#                                  fl_servico_internet_dsl  \
# fl_inativo                                     -0.124214
# fl_maior_65_anos                               -0.108322
# fl_tem_parceiro                                -0.000851
# fl_dependentes                                  0.052010
# meses_contrato                                  0.013274
# fl_servico_telefonico                          -0.452425
# fl_multiplas_linhas                            -0.199920
# fl_servico_seguranca_online                     0.321269
# fl_servico_backup_online                        0.157884
# fl_servico_protecao_dispositivo                 0.146291
# fl_servico_suporte_tech                         0.313118
# fl_servico_tv_cabo                              0.016274
# fl_servico_stream                               0.025698
# fl_sem_papel                                   -0.063121
# valor_servico_diario                           -0.160211
# valor_servico_mensal                           -0.160189
# valor_servico_total                            -0.052448
# fl_servico_internet_dsl                         1.000000
# fl_servico_internet_fibra_otica                -0.640987
# fl_sem_servico_internet                        -0.380635
# fl_contrato_anual                               0.046795
# fl_contrato_bienal                              0.031714
# fl_contrato_mensal                             -0.065509
# fl_pagamento_ccredito                           0.051438
# fl_pagamento_cheque_correio                     0.041899
# fl_pagamento_cheque_eletronico                 -0.104418
# fl_pagamento_transf_bancaria                    0.025476
#
#                                  fl_servico_internet_fibra_otica  \
# fl_inativo                                              0.308020
# fl_maior_65_anos                                        0.255338
# fl_tem_parceiro                                         0.000304
# fl_dependentes                                         -0.165818
# meses_contrato                                          0.019720
# fl_servico_telefonico                                   0.289999
# fl_multiplas_linhas                                     0.366083
# fl_servico_seguranca_online                            -0.030696
# fl_servico_backup_online                                0.165651
# fl_servico_protecao_dispositivo                         0.176049
# fl_servico_suporte_tech                                -0.020492
# fl_servico_tv_cabo                                      0.329349
# fl_servico_stream                                       0.322923
# fl_sem_papel                                            0.326853
# valor_servico_diario                                    0.787091
# valor_servico_mensal                                    0.787066
# valor_servico_total                                     0.361640
# fl_servico_internet_dsl                                -0.640987
# fl_servico_internet_fibra_otica                         1.000000
# fl_sem_servico_internet                                -0.465793
# fl_contrato_anual                                      -0.076324
# fl_contrato_bienal                                     -0.211526
# fl_contrato_mensal                                      0.244164
# fl_pagamento_ccredito                                  -0.050077
# fl_pagamento_cheque_correio                            -0.306834
# fl_pagamento_cheque_eletronico                          0.336410
# fl_pagamento_transf_bancaria                           -0.022624
#
#                                  fl_sem_servico_internet  fl_contrato_anual  \
# fl_inativo                                     -0.227890          -0.177820
# fl_maior_65_anos                               -0.182742          -0.046262
# fl_tem_parceiro                                 0.000615           0.082783
# fl_dependentes                                  0.139812           0.068368
# meses_contrato                                 -0.039062           0.202570
# fl_servico_telefonico                           0.172209          -0.002791
# fl_multiplas_linhas                            -0.210564          -0.003794
# fl_servico_seguranca_online                    -0.333403           0.100162
# fl_servico_backup_online                       -0.381593           0.083722
# fl_servico_protecao_dispositivo                -0.380754           0.102495
# fl_servico_suporte_tech                        -0.336298           0.095775
# fl_servico_tv_cabo                             -0.415552           0.061612
# fl_servico_stream                              -0.418675           0.064926
# fl_sem_papel                                   -0.321013          -0.051391
# valor_servico_diario                           -0.763562           0.004849
# valor_servico_mensal                           -0.763557           0.004904
# valor_servico_total                            -0.375229           0.170807
# fl_servico_internet_dsl                        -0.380635           0.046795
# fl_servico_internet_fibra_otica                -0.465793          -0.076324
# fl_sem_servico_internet                         1.000000           0.038004
# fl_contrato_anual                               0.038004           1.000000
# fl_contrato_bienal                              0.218278          -0.289510
# fl_contrato_mensal                             -0.218639          -0.568744
# fl_pagamento_ccredito                           0.001030           0.067589
# fl_pagamento_cheque_correio                     0.321361          -0.000116
# fl_pagamento_cheque_eletronico                 -0.284917          -0.109130
# fl_pagamento_transf_bancaria                   -0.002113           0.057451
#
#                                  fl_contrato_bienal  fl_contrato_mensal  \
# fl_inativo                                -0.302253            0.405103
# fl_maior_65_anos                          -0.117000            0.138360
# fl_tem_parceiro                            0.248091           -0.280865
# fl_dependentes                             0.204613           -0.231720
# meses_contrato                             0.558533           -0.645561
# fl_servico_telefonico                      0.003519           -0.000742
# fl_multiplas_linhas                        0.106253           -0.088203
# fl_servico_seguranca_online                0.191773           -0.246679
# fl_servico_backup_online                   0.111400           -0.164172
# fl_servico_protecao_dispositivo            0.165096           -0.225662
# fl_servico_suporte_tech                    0.240824           -0.285241
# fl_servico_tv_cabo                         0.072049           -0.112282
# fl_servico_stream                          0.073960           -0.116633
# fl_sem_papel                              -0.147889            0.169096
# valor_servico_diario                      -0.074710            0.060235
# valor_servico_mensal                      -0.074681            0.060165
# valor_servico_total                        0.354539           -0.444299
# fl_servico_internet_dsl                    0.031714           -0.065509
# fl_servico_internet_fibra_otica           -0.211526            0.244164
# fl_sem_servico_internet                    0.218278           -0.218639
# fl_contrato_anual                         -0.289510           -0.568744
# fl_contrato_bienal                         1.000000           -0.622633
# fl_contrato_mensal                        -0.622633            1.000000
# fl_pagamento_ccredito                      0.173265           -0.204145
# fl_pagamento_cheque_correio               -0.004705            0.004138
# fl_pagamento_cheque_eletronico            -0.282138            0.331661
# fl_pagamento_transf_bancaria               0.154471           -0.179707
#
#                                  fl_pagamento_ccredito  \
# fl_inativo                                   -0.134302
# fl_maior_65_anos                             -0.024135
# fl_tem_parceiro                               0.082029
# fl_dependentes                                0.060267
# meses_contrato                                0.233006
# fl_servico_telefonico                        -0.007721
# fl_multiplas_linhas                           0.060048
# fl_servico_seguranca_online                   0.115721
# fl_servico_backup_online                      0.090785
# fl_servico_protecao_dispositivo               0.111554
# fl_servico_suporte_tech                       0.117272
# fl_servico_tv_cabo                            0.040433
# fl_servico_stream                             0.048575
# fl_sem_papel                                 -0.013589
# valor_servico_diario                          0.030547
# valor_servico_mensal                          0.030550
# valor_servico_total                           0.182913
# fl_servico_internet_dsl                       0.051438
# fl_servico_internet_fibra_otica              -0.050077
# fl_sem_servico_internet                       0.001030
# fl_contrato_anual                             0.067589
# fl_contrato_bienal                            0.173265
# fl_contrato_mensal                           -0.204145
# fl_pagamento_ccredito                         1.000000
# fl_pagamento_cheque_correio                  -0.286049
# fl_pagamento_cheque_eletronico               -0.373322
# fl_pagamento_transf_bancaria                 -0.278215
#
#                                  fl_pagamento_cheque_correio  \
# fl_inativo                                         -0.091683
# fl_maior_65_anos                                   -0.153477
# fl_tem_parceiro                                    -0.095125
# fl_dependentes                                      0.059071
# meses_contrato                                     -0.233852
# fl_servico_telefonico                              -0.003319
# fl_multiplas_linhas                                -0.227206
# fl_servico_seguranca_online                        -0.080798
# fl_servico_backup_online                           -0.174164
# fl_servico_protecao_dispositivo                    -0.187373
# fl_servico_suporte_tech                            -0.085509
# fl_servico_tv_cabo                                 -0.247742
# fl_servico_stream                                  -0.250595
# fl_sem_papel                                       -0.205398
# valor_servico_diario                               -0.377436
# valor_servico_mensal                               -0.377437
# valor_servico_total                                -0.295740
# fl_servico_internet_dsl                             0.041899
# fl_servico_internet_fibra_otica                    -0.306834
# fl_sem_servico_internet                             0.321361
# fl_contrato_anual                                  -0.000116
# fl_contrato_bienal                                 -0.004705
# fl_contrato_mensal                                  0.004138
# fl_pagamento_ccredito                              -0.286049
# fl_pagamento_cheque_correio                         1.000000
# fl_pagamento_cheque_eletronico                     -0.387372
# fl_pagamento_transf_bancaria                       -0.288685
#
#                                  fl_pagamento_cheque_eletronico  \
# fl_inativo                                             0.301919
# fl_maior_65_anos                                       0.171718
# fl_tem_parceiro                                       -0.083852
# fl_dependentes                                        -0.150642
# meses_contrato                                        -0.208363
# fl_servico_telefonico                                  0.003062
# fl_multiplas_linhas                                    0.083618
# fl_servico_seguranca_online                           -0.112338
# fl_servico_backup_online                              -0.000408
# fl_servico_protecao_dispositivo                       -0.003351
# fl_servico_suporte_tech                               -0.114839
# fl_servico_tv_cabo                                     0.144626
# fl_servico_stream                                      0.137966
# fl_sem_papel                                           0.208865
# valor_servico_diario                                   0.271650
# valor_servico_mensal                                   0.271625
# valor_servico_total                                   -0.059268
# fl_servico_internet_dsl                               -0.104418
# fl_servico_internet_fibra_otica                        0.336410
# fl_sem_servico_internet                               -0.284917
# fl_contrato_anual                                     -0.109130
# fl_contrato_bienal                                    -0.282138
# fl_contrato_mensal                                     0.331661
# fl_pagamento_ccredito                                 -0.373322
# fl_pagamento_cheque_correio                           -0.387372
# fl_pagamento_cheque_eletronico                         1.000000
# fl_pagamento_transf_bancaria                          -0.376762
#
#                                  fl_pagamento_transf_bancaria
# fl_inativo                                          -0.117937
# fl_maior_65_anos                                    -0.016159
# fl_tem_parceiro                                      0.110706
# fl_dependentes                                       0.052021
# meses_contrato                                       0.243510
# fl_servico_telefonico                                0.007556
# fl_multiplas_linhas                                  0.075527
# fl_servico_seguranca_online                          0.095158
# fl_servico_backup_online                             0.087004
# fl_servico_protecao_dispositivo                      0.083115
# fl_servico_suporte_tech                              0.101252
# fl_servico_tv_cabo                                   0.046252
# fl_servico_stream                                    0.048652
# fl_sem_papel                                        -0.016332
# valor_servico_diario                                 0.042785
# valor_servico_mensal                                 0.042812
# valor_servico_total                                  0.185994
# fl_servico_internet_dsl                              0.025476
# fl_servico_internet_fibra_otica                     -0.022624
# fl_sem_servico_internet                             -0.002113
# fl_contrato_anual                                    0.057451
# fl_contrato_bienal                                   0.154471
# fl_contrato_mensal                                  -0.179707
# fl_pagamento_ccredito                               -0.278215
# fl_pagamento_cheque_correio                         -0.288685
# fl_pagamento_cheque_eletronico                      -0.376762
# fl_pagamento_transf_bancaria                         1.000000
#
# [27 rows x 27 columns]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 16))

sns.heatmap(df_corr.corr(), annot=True)
plt.show()

# %%
df_corr.to_json('../Dados/df_para_ml.json')

# %% [markdown]
# ### Conclusão

# %% [markdown]
# De acordo com as análises visuais, os indicadores mais fortes para o Churn são: Tipo de serviço de internet (Fibra Ótica), Valores (os churns apresentam maior concentração em clientes que os valores totais alto em relação ao tempo de contrato, além de ter um valor médio mensal maior do que os clientes não churn)
